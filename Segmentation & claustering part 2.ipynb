# %% [markdown]
# <h1><center>Segmenting and clustering in Toronto´s neighborhood-part2</center></h1>

# %% [markdown]
# Import libraries nedeed

# %%
import pandas as pd
import numpy as np
import geocoder #I tried to do by this code but don't had a result

# %%
df=pd.read_csv('Canada.csv')
df
# Out:
#      Unnamed: 0 Postal Code           Borough  \
# 0             0         M3A        North York
# 1             1         M4A        North York
# 2             2         M5A  Downtown Toronto
# 3             3         M6A        North York
# 4             4         M7A  Downtown Toronto
# ..          ...         ...               ...
# 98           98         M8X         Etobicoke
# 99           99         M4Y  Downtown Toronto
# 100         100         M7Y      East Toronto
# 101         101         M8Y         Etobicoke
# 102         102         M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# ...

# %% [markdown]
# Drop the First column

# %%
df=df.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# ...

# %% [markdown]
# Reading the CSV file contening the latitude and longitud

# %%
df2=pd.read_csv('Geospatial_Coordinates.csv')
df2
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %% [markdown]
# With the pandas method named merge we can combine two dataframe doing match with their respective labels and values

# %%
postal_location=pd.merge(df,df2)
postal_location.columns
# Out:
# Index(['Postal Code', 'Borough', 'Neighbourhood', 'Latitude', 'Longitude'], dtype='object')

# %%
postal_location.head()
# Out:
#   Postal Code           Borough                                Neighbourhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %%
postal_location.to_csv('postal_location.csv')
